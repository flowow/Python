# %%
a=[1,2,3]

a

# %%
a=[1,2,3]

# %% [markdown]
# 단축키를 배우고 있습니다

# %% [markdown]
# ###### 단축키
# ##### 단축키
# #### 단축키
# ### 단축키
# ## 단축키
# # 단축키

# %%
import pandas as pd
a=[1,2,3]
a
# Out:
# [1, 2, 3]

# %%
scientists=pd.read_csv("../data/scientists.csv")
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
print(scientists['Died'].dtype)
# Out:
# object

# %%
#문자열은 날짜로 인식 못함 문자열로 구성된 날짜 데이터를 날짜 형식으로 변경해줘야 함

# %% [markdown]
# ## 문자열형을 날짜형으로 변경하는 방법

# %%
born_datetime=pd.to_datetime(scientists['Born'],format="%Y-%m-%d")
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime=pd.to_datetime(scientists['Died'],format="%Y-%m-%d")
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'],scientists['died_dt']=(born_datetime,died_datetime)
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt age_days_dt  a
# 0 1958-04-16  13779 days  0
# 1 1937-10-16  22404 days  1
# 2 1910-08-13  32964 days  2
# 3 1934-07-04  24345 days  3
# 4 1964-04-14  20777 days  4

# %%
scientists.shape
# Out:
# (8, 7)

# %%
scientists['age_days_dt']=scientists['died_dt']-scientists['born_dt']
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# 데이터프레임과 시리즈 데이터 혼합

# %%
scientists['Age']
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
import random
random.seed(1004)
random.shuffle(scientists['Age'])
scientists['Age']
# Out:
# C:\Users\user\anac\lib\random.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   x[i], x[j] = x[j], x[i]
# 0    90
# 1    66
# 2    77
# 3    61
# 4    56
# 5    45
# 6    37
# 7    41
# Name: Age, dtype: int64

# %%
scientists.columns
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt', 'a'],
#       dtype='object')

# %%
scientists_dropped=scientists.drop(['Age'],axis=1)

# %%
scientists_dropped.columns
# Out:
# Index(['Name', 'Born', 'Died', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt', 'a'],
#       dtype='object')

# %%
names=scientists['Name']
names
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
names.to_pickle("../output/cur_names.pickle")  #../는 지금 위치에서 한단계 위로 ../../는 두단계 위

# %%
names.to_excel("cur_names_xls.xls")

# %%
sci_n_fromp=pd.read_pickle("../output/cur_names.pickle")
print(sci_n_fromp)
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
names.to_csv("../output/scientist_names_series.csv")
scientists.to_csv("../output/scientists_df_tsv.tsv",sep="\t")

# %%
names_df=names.to_frame()
print(type(names_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
names_df.to_excel("../output/scientist_names_series_df.xls")

# %%
names_df.to_excel("../output/scientist_names_series_df.xlsx")

# %% [markdown]
# # 데이터 시각화의 중요성
# -분석 결과 보고
# -데이터의 패턴 파악
# -두 데이터 셋의 통계치(평균,상관관계,분산,회귀선 등)들이 거의 유사할 때 비슷한 데이터로 간주하는 오류 방지->즉 통계치로만 판단x

# %%
import seaborn as sns
anscombe=sns.load_dataset("anscombe")
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1=anscombe[anscombe['dataset']=='I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_1['x'],dataset_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %%
dataset_1=anscombe[anscombe['dataset']=='I']
dataset_2=anscombe[anscombe['dataset']=='II']
dataset_3=anscombe[anscombe['dataset']=='III']
dataset_4=anscombe[anscombe['dataset']=='IV']

# %%
fig=plt.figure()
axes1=fig.add_subplot(2,2,1) #세번째 1은 시작하는 위치
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')

# %%
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
# Out:
# Text(0.5,1,'dataset_4')

# %%
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.suptitle("Anscombe Data") #전체 title 붙이기
fig.tight_layout() #tight 하게ㅡ 그렇지만 겹치지 않게
